# %% [markdown]
# # BYOL Demo
#
# An end-to-end demonstration of BYOL in action, using STL10 as a toy dataset.

# %% [markdown]
# ### Install dependencies
#
# PyTorch and Torchvision are pre-installed in Colab instances, so no need to worry about those.

# %%
# Install dependencies.  Note that pytorch and torchvision are pre-installed 
# in standard Colab instances, so no need to worry about those.
# !pip install -q kornia pytorch_lightning
# !pip install torchinfo
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.1/628.1 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.6/718.6 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 21.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 22.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 32.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 15.4 MB/s eta 0:00:00
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.2

# %%
# !pip install pytorch_lightning==1.9.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch_lightning==1.9.3
#   Downloading pytorch_lightning-1.9.3-py3-none-any.whl (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.4/826.4 kB 52.3 MB/s eta 0:00:00
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.9.3) (0.11.4)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.9.3) (4.65.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.9.3) (23.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.9.3) (4.5.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.9.3) (1.22.4)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.9.3) (0.8.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.9.3) (6.0)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.9.3) (2.0.0+cu118)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.9.3) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (2.27.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.9/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (3.8.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.10.0->pytorch_lightning==1.9.3) (3.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.10.0->pytorch_lightning==1.9.3) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.10.0->pytorch_lightning==1.9.3) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.10.0->pytorch_lightning==1.9.3) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.10.0->pytorch_lightning==1.9.3) (3.1.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.10.0->pytorch_lightning==1.9.3) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.10.0->pytorch_lightning==1.9.3) (16.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (1.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (4.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.10.0->pytorch_lightning==1.9.3) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning==1.9.3) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.10.0->pytorch_lightning==1.9.3) (1.3.0)
# Installing collected packages: pytorch_lightning
#   Attempting uninstall: pytorch_lightning
#     Found existing installation: pytorch-lightning 2.0.1.post0
#     Uninstalling pytorch-lightning-2.0.1.post0:
#       Successfully uninstalled pytorch-lightning-2.0.1.post0
# Successfully installed pytorch_lightning-1.9.3

# %% [markdown]
# ### Data Augmentations

# %%
import random
from typing import Callable, Tuple

from kornia import augmentation as aug
from kornia import filters
from kornia.geometry import transform as tf
import torch
from torch import nn, Tensor
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.callbacks.early_stopping import EarlyStopping

from os import cpu_count

from torch.utils.data import DataLoader
from torchvision.models import resnet18, resnet50

# %%
class RandomApply(nn.Module):
    def __init__(self, fn: Callable, p: float):
        super().__init__()
        self.fn = fn
        self.p = p

    def forward(self, x: Tensor) -> Tensor:
        return x if random.random() > self.p else self.fn(x)


def default_augmentation(image_size: Tuple[int, int] = (224, 224)) -> nn.Module:
    return nn.Sequential(
        tf.Resize(size=image_size),
        RandomApply(aug.ColorJitter(0.8, 0.8, 0.8, 0.2), p=0.8),
        aug.RandomGrayscale(p=0.2),
        aug.RandomHorizontalFlip(),
        RandomApply(filters.GaussianBlur2d((3, 3), (1.5, 1.5)), p=0.1),
        aug.RandomResizedCrop(size=image_size),
        aug.Normalize(
            mean=torch.tensor([0.485, 0.456, 0.406]),
            std=torch.tensor([0.229, 0.224, 0.225]),
        ),
    )

# %% [markdown]
# ### Encoder Wrapper
#
# Enables us to work with *any* model, not just ResNet18 which I chose for this demo.

# %%
from typing import Union


def mlp(dim: int, projection_size: int = 256, hidden_size: int = 4096) -> nn.Module:
    return nn.Sequential(
        nn.Linear(dim, hidden_size),
        nn.BatchNorm1d(hidden_size),
        nn.ReLU(inplace=True),
        nn.Linear(hidden_size, projection_size),
    )


class EncoderWrapper(nn.Module):
    def __init__(
        self,
        model: nn.Module,
        projection_size: int = 256,
        hidden_size: int = 4096,
        layer: Union[str, int] = -2,
    ):
        super().__init__()
        self.model = model
        self.projection_size = projection_size
        self.hidden_size = hidden_size
        self.layer = layer

        self._projector = None
        self._projector_dim = None
        self._encoded = torch.empty(0)
        self._register_hook()

    @property
    def projector(self):
        if self._projector is None:
            self._projector = mlp(
                self._projector_dim, self.projection_size, self.hidden_size
            )
        return self._projector

    def _hook(self, _, __, output):
        output = output.flatten(start_dim=1)
        if self._projector_dim is None:
            self._projector_dim = output.shape[-1]
        self._encoded = self.projector(output)

    def _register_hook(self):
        if isinstance(self.layer, str):
            layer = dict([*self.model.named_modules()])[self.layer]
        else:
            layer = list(self.model.children())[self.layer]

        layer.register_forward_hook(self._hook)

    def forward(self, x: Tensor) -> Tensor:
        _ = self.model(x)
        return self._encoded

# %% [markdown]
# ### BYOL and Training Code
#
# Encapsulate BYOL into a single module.  I use PyTorch Lightning here, because it makes training very easy.  This code also works for multi-GPU or TPU training, and experiments are logged automatically.

# %%
from copy import deepcopy
from itertools import chain
from typing import Dict, List

import pytorch_lightning as pl
from torch import optim
import torch.nn.functional as f


def normalized_mse(x: Tensor, y: Tensor) -> Tensor:
    x = f.normalize(x, dim=-1)
    y = f.normalize(y, dim=-1)
    return 2 - 2 * (x * y).sum(dim=-1)


class BYOL(pl.LightningModule):
    def __init__(
        self,
        model: nn.Module,
        image_size: Tuple[int, int] = (128, 128),
        hidden_layer: Union[str, int] = -2,
        projection_size: int = 256,
        hidden_size: int = 4096,
        augment_fn: Callable = None,
        beta: float = 0.999,
        **hparams,
    ):
        super().__init__()
        self.augment = default_augmentation(image_size) if augment_fn is None else augment_fn
        self.beta = beta
        self.encoder = EncoderWrapper(
            model, projection_size, hidden_size, layer=hidden_layer
        )
        self.predictor = nn.Linear(projection_size, projection_size, hidden_size)
        # self.hparams = hparams
        self._target = None

        self.encoder(torch.zeros(2, 3, *image_size))

    def forward(self, x: Tensor) -> Tensor:
        return self.predictor(self.encoder(x))

    @property
    def target(self):
        if self._target is None:
            self._target = deepcopy(self.encoder)
        return self._target

    def update_target(self):
        for p, pt in zip(self.encoder.parameters(), self.target.parameters()):
            pt.data = self.beta * pt.data + (1 - self.beta) * p.data

    # --- Methods required for PyTorch Lightning only! ---

    def configure_optimizers(self):
        optimizer = getattr(optim, self.hparams.get("optimizer", "Adam"))
        lr = self.hparams.get("lr", 1e-4)
        weight_decay = self.hparams.get("weight_decay", 1e-6)
        return optimizer(self.parameters(), lr=lr, weight_decay=weight_decay)

    def training_step(self, batch, *_) -> Dict[str, Union[Tensor, Dict]]:
        x = batch[0]
        with torch.no_grad():
            x1, x2 = self.augment(x), self.augment(x)

        pred1, pred2 = self.forward(x1), self.forward(x2)
        with torch.no_grad():
            targ1, targ2 = self.target(x1), self.target(x2)
        loss = torch.mean(normalized_mse(pred1, targ2) + normalized_mse(pred2, targ1))

        self.log("train_loss", loss.item())
        self.update_target()

        return {"loss": loss}

    @torch.no_grad()
    def validation_step(self, batch, *_) -> Dict[str, Union[Tensor, Dict]]:
        x = batch[0]
        x1, x2 = self.augment(x), self.augment(x)
        pred1, pred2 = self.forward(x1), self.forward(x2)
        targ1, targ2 = self.target(x1), self.target(x2)
        loss = torch.mean(normalized_mse(pred1, targ2) + normalized_mse(pred2, targ1))

        return {"loss": loss}

    @torch.no_grad()
    def validation_epoch_end(self, outputs: List[Dict]) -> Dict:
        val_loss = sum(x["loss"] for x in outputs) / len(outputs)
        self.log("val_loss", val_loss.item())

# %% [markdown]
# ### Supervised Training Module

# %%
class SupervisedLightningModule(pl.LightningModule):
    def __init__(self, model: nn.Module, **hparams):
        super().__init__()
        self.model = model
        self.save_hyperparameters()

    def forward(self, x: Tensor) -> Tensor:
        return self.model(x)

    def configure_optimizers(self):
        optimizer = getattr(optim, self.hparams.get("optimizer", "Adam"))
        lr = self.hparams.get("lr", 1e-4)
        weight_decay = self.hparams.get("weight_decay", 1e-6)
        return optimizer(self.parameters(), lr=lr, weight_decay=weight_decay)

    def training_step(self, batch, *_) -> Dict[str, Union[Tensor, Dict]]:
        x, y = batch
        loss = f.cross_entropy(self.forward(x), y)
        self.log("train_loss", loss.item(), prog_bar=True, on_step=False, on_epoch=True)
        return {"loss": loss}

    @torch.no_grad()
    def validation_step(self, batch, *_) -> Dict[str, Union[Tensor, Dict]]:
        x, y = batch
        loss = f.cross_entropy(self.forward(x), y)
        self.log("val_loss", loss.item(), prog_bar=True, on_step=False, on_epoch=True) 
        return {"loss": loss}

    @torch.no_grad()
    def validation_epoch_end(self, outputs: List[Dict]) -> Dict:
        val_loss = sum(x["loss"] for x in outputs) / len(outputs)
        self.log("val_loss", val_loss.item())

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unrar x "/content/drive/MyDrive/Capstone dataset/FGNET73.rar"
# Out:
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/Capstone dataset/FGNET73.rar
#
# Creating    FGNET73                                                   OK
# Creating    FGNET73/test                                              OK
# Creating    FGNET73/test/001                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/002                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/003                                          OK
#   OK
#   OK
# Creating    FGNET73/test/004                                          OK
#   OK
#   OK
# Creating    FGNET73/test/005                                          OK
#   OK
#   OK
# Creating    FGNET73/test/006                                          OK
#   OK
#   OK
# Creating    FGNET73/test/007                                          OK
#   OK
#   OK
# Creating    FGNET73/test/008                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/009                                          OK
#   OK
#   OK
# Creating    FGNET73/test/010                                          OK
#   OK
#   OK
# Creating    FGNET73/test/011                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/012                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/013                                          OK
#   OK
#   OK
# Creating    FGNET73/test/014                                          OK
#   OK
#   OK
# Creating    FGNET73/test/015                                          OK
#   OK
#   OK
# Creating    FGNET73/test/016                                          OK
#   OK
#   OK
# Creating    FGNET73/test/017                                          OK
#   OK
#   OK
# Creating    FGNET73/test/018                                          OK
#   OK
#   OK
# Creating    FGNET73/test/019                                          OK
#   OK
#   OK
# Creating    FGNET73/test/020                                          OK
#   OK
#   OK
# Creating    FGNET73/test/021                                          OK
#   OK
#   OK
# Creating    FGNET73/test/022                                          OK
#   OK
#   OK
# Creating    FGNET73/test/023                                          OK
#   OK
#   OK
# Creating    FGNET73/test/024                                          OK
#   OK
#   OK
# Creating    FGNET73/test/025                                          OK
#   OK
#   OK
# Creating    FGNET73/test/026                                          OK
#   OK
#   OK
# Creating    FGNET73/test/027                                          OK
#   OK
#   OK
# Creating    FGNET73/test/028                                          OK
#   OK
#   OK
# Creating    FGNET73/test/029                                          OK
#   OK
#   OK
# Creating    FGNET73/test/030                                          OK
#   OK
#   OK
# Creating    FGNET73/test/031                                          OK
#   OK
#   OK
# Creating    FGNET73/test/032                                          OK
#   OK
#   OK
# Creating    FGNET73/test/033                                          OK
#   OK
#   OK
# Creating    FGNET73/test/034                                          OK
#   OK
#   OK
# Creating    FGNET73/test/035                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/036                                          OK
#   OK
#   OK
# Creating    FGNET73/test/037                                          OK
#   OK
#   OK
# Creating    FGNET73/test/038                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/039                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/040                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/041                                          OK
#   OK
#   OK
# Creating    FGNET73/test/042                                          OK
#   OK
#   OK
# Creating    FGNET73/test/043                                          OK
#   OK
#   OK
# Creating    FGNET73/test/044                                          OK
#   OK
#   OK
# Creating    FGNET73/test/045                                          OK
#   OK
#   OK
# Creating    FGNET73/test/046                                          OK
#   OK
#   OK
# Creating    FGNET73/test/047                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/048                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/049                                          OK
#   OK
#   OK
# Creating    FGNET73/test/050                                          OK
#   OK
#   OK
# Creating    FGNET73/test/051                                          OK
#   OK
#   OK
# Creating    FGNET73/test/052                                          OK
#   OK
#   OK
# Creating    FGNET73/test/053                                          OK
#   OK
#   OK
# Creating    FGNET73/test/054                                          OK
#   OK
#   OK
# Creating    FGNET73/test/055                                          OK
#   OK
#   OK
# Creating    FGNET73/test/056                                          OK
#   OK
#   OK
# Creating    FGNET73/test/057                                          OK
#   OK
#   OK
# Creating    FGNET73/test/058                                          OK
#   OK
#   OK
# Creating    FGNET73/test/059                                          OK
#   OK
#   OK
# Creating    FGNET73/test/060                                          OK
#   OK
#   OK
# Creating    FGNET73/test/061                                          OK
#   OK
#   OK
# Creating    FGNET73/test/062                                          OK
#   OK
#   OK
# Creating    FGNET73/test/063                                          OK
#   OK
#   OK
# Creating    FGNET73/test/064                                          OK
#   OK
# Creating    FGNET73/test/065                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/066                                          OK
#   OK
#   OK
# Creating    FGNET73/test/067                                          OK
#   OK
#   OK
# Creating    FGNET73/test/068                                          OK
#   OK
#   OK
# Creating    FGNET73/test/069                                          OK
#   OK
#   OK
# Creating    FGNET73/test/070                                          OK
#   OK
#   OK
# Creating    FGNET73/test/071                                          OK
#   OK
#   OK
# Creating    FGNET73/test/072                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/073                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/074                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/075                                          OK
#   OK
#   OK
# Creating    FGNET73/test/076                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/077                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/078                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/079                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/080                                          OK
#   OK
#   OK
#   OK
# Creating    FGNET73/test/081                                          OK
#   OK
#   OK
# Creating    FGNET73/test/082                                          OK
#   OK
#   OK
# Creating    FGNET73/train                                             OK
# Creating    FGNET73/train/001                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/002                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/003                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/004                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/005                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/006                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/007                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/008                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/009                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/010                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/011                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/012                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/013                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/014                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/015                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/016                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/017                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/018                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/019                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/020                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/021                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/022                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/023                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/024                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/025                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/026                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/027                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/028                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/029                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/030                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/031                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/032                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/033                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/034                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/035                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/036                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/037                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/038                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/039                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/040                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/041                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/042                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/043                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/044                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/045                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/046                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/047                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/048                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/049                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/050                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/051                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/052                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/053                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/054                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/055                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/056                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/057                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/058                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/059                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/060                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/061                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/062                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/063                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/064                                         OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/065                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/066                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/067                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/068                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/069                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/070                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/071                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/072                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/073                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/074                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/075                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/076                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/077                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/078                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/079                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/080                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/081                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/train/082                                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    FGNET73/val                                               OK
# Creating    FGNET73/val/001                                           OK
#   OK
#   OK
# Creating    FGNET73/val/002                                           OK
#   OK
#   OK
# Creating    FGNET73/val/003                                           OK
#   OK
#   OK
# Creating    FGNET73/val/004                                           OK
#   OK
#   OK
# Creating    FGNET73/val/005                                           OK
#   OK
#   OK
# Creating    FGNET73/val/006                                           OK
#   OK
#   OK
# Creating    FGNET73/val/007                                           OK
#   OK
# Creating    FGNET73/val/008                                           OK
#   OK
#   OK
# Creating    FGNET73/val/009                                           OK
#   OK
#   OK
# Creating    FGNET73/val/010                                           OK
#   OK
#   OK
# Creating    FGNET73/val/011                                           OK
#   OK
#   OK
# Creating    FGNET73/val/012                                           OK
#   OK
#   OK
# Creating    FGNET73/val/013                                           OK
#   OK
#   OK
# Creating    FGNET73/val/014                                           OK
#   OK
# Creating    FGNET73/val/015                                           OK
#   OK
#   OK
# Creating    FGNET73/val/016                                           OK
#   OK
#   OK
# Creating    FGNET73/val/017                                           OK
#   OK
#   OK
# Creating    FGNET73/val/018                                           OK
#   OK
#   OK
# Creating    FGNET73/val/019                                           OK
#   OK
# Creating    FGNET73/val/020                                           OK
#   OK
#   OK
# Creating    FGNET73/val/021                                           OK
#   OK
#   OK
# Creating    FGNET73/val/022                                           OK
#   OK
#   OK
# Creating    FGNET73/val/023                                           OK
#   OK
#   OK
# Creating    FGNET73/val/024                                           OK
#   OK
#   OK
# Creating    FGNET73/val/025                                           OK
#   OK
#   OK
# Creating    FGNET73/val/026                                           OK
#   OK
#   OK
# Creating    FGNET73/val/027                                           OK
#   OK
#   OK
# Creating    FGNET73/val/028                                           OK
#   OK
#   OK
# Creating    FGNET73/val/029                                           OK
#   OK
#   OK
# Creating    FGNET73/val/030                                           OK
#   OK
#   OK
# Creating    FGNET73/val/031                                           OK
#   OK
#   OK
# Creating    FGNET73/val/032                                           OK
#   OK
#   OK
# Creating    FGNET73/val/033                                           OK
#   OK
#   OK
# Creating    FGNET73/val/034                                           OK
#   OK
#   OK
# Creating    FGNET73/val/035                                           OK
#   OK
#   OK
# Creating    FGNET73/val/036                                           OK
#   OK
#   OK
# Creating    FGNET73/val/037                                           OK
#   OK
#   OK
# Creating    FGNET73/val/038                                           OK
#   OK
#   OK
# Creating    FGNET73/val/039                                           OK
#   OK
#   OK
# Creating    FGNET73/val/040                                           OK
#   OK
#   OK
# Creating    FGNET73/val/041                                           OK
#   OK
# Creating    FGNET73/val/042                                           OK
#   OK
#   OK
# Creating    FGNET73/val/043                                           OK
#   OK
#   OK
# Creating    FGNET73/val/044                                           OK
#   OK
# Creating    FGNET73/val/045                                           OK
#   OK
#   OK
# Creating    FGNET73/val/046                                           OK
#   OK
#   OK
# Creating    FGNET73/val/047                                           OK
#   OK
#   OK
# Creating    FGNET73/val/048                                           OK
#   OK
#   OK
# Creating    FGNET73/val/049                                           OK
#   OK
# Creating    FGNET73/val/050                                           OK
#   OK
# Creating    FGNET73/val/051                                           OK
#   OK
#   OK
# Creating    FGNET73/val/052                                           OK
#   OK
#   OK
# Creating    FGNET73/val/053                                           OK
#   OK
#   OK
# Creating    FGNET73/val/054                                           OK
#   OK
#   OK
# Creating    FGNET73/val/055                                           OK
#   OK
# Creating    FGNET73/val/056                                           OK
#   OK
# Creating    FGNET73/val/057                                           OK
#   OK
# Creating    FGNET73/val/058                                           OK
#   OK
#   OK
# Creating    FGNET73/val/059                                           OK
#   OK
# Creating    FGNET73/val/060                                           OK
#   OK
#   OK
# Creating    FGNET73/val/061                                           OK
#   OK
#   OK
# Creating    FGNET73/val/062                                           OK
#   OK
#   OK
# Creating    FGNET73/val/063                                           OK
#   OK
# Creating    FGNET73/val/064                                           OK
#   OK
# Creating    FGNET73/val/065                                           OK
#   OK
#   OK
# Creating    FGNET73/val/066                                           OK
#   OK
#   OK
# Creating    FGNET73/val/067                                           OK
#   OK
# Creating    FGNET73/val/068                                           OK
#   OK
# Creating    FGNET73/val/069                                           OK
#   OK
#   OK
# Creating    FGNET73/val/070                                           OK
#   OK
#   OK
# Creating    FGNET73/val/071                                           OK
#   OK
#   OK
# Creating    FGNET73/val/072                                           OK
#   OK
#   OK
# Creating    FGNET73/val/073                                           OK
#   OK
#   OK
# Creating    FGNET73/val/074                                           OK
#   OK
#   OK
# Creating    FGNET73/val/075                                           OK
#   OK
# Creating    FGNET73/val/076                                           OK
#   OK
#   OK
#   OK
# Creating    FGNET73/val/077                                           OK
#   OK
#   OK
# Creating    FGNET73/val/078                                           OK
#   OK
#   OK
# Creating    FGNET73/val/079                                           OK
#   OK
#   OK
# Creating    FGNET73/val/080                                           OK
#   OK
#   OK
# Creating    FGNET73/val/081                                           OK
#   OK
#   OK
# Creating    FGNET73/val/082                                           OK
#   OK
#   OK
# All OK

# %% [markdown]
# ### Supervised Training without BYOL
#
# Run through supervised training, and measure the accuracy.  Performance should be pretty good already.

# %%
from torchvision import datasets, models, transforms

input_path = "/content/FGNET73"
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ]),

    'validation':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        normalize
    ]),
    'test':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        normalize
    ])
}

image_datasets = {
    'train': 
    datasets.ImageFolder(input_path + '/train', data_transforms['train']),
    'validation': 
    datasets.ImageFolder(input_path + '/val', data_transforms['validation']),
    'test': 
    datasets.ImageFolder(input_path + '/test', data_transforms['test'])
}


train_dataloader = torch.utils.data.DataLoader(image_datasets['train'],
                                 batch_size=32,
                                 shuffle=True)
val_dataloader = torch.utils.data.DataLoader(image_datasets['validation'],
                                 batch_size=32,
                                 shuffle=False)
test_dataloader = torch.utils.data.DataLoader(image_datasets['test'],
                                 batch_size=32,
                                 shuffle=False)

class_names = image_datasets['train'].classes

# %%
#load pretrain
model = resnet18(pretrained=True)
num_ftrs = model.fc.in_features  
model.fc = nn.Sequential(
               nn.Linear(num_ftrs, 256),
               nn.ReLU(inplace=True),
               nn.Dropout(0.2),
               nn.Linear(256, len(class_names)))
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 338MB/s]

# %%
# from torchinfo import summary
# summary(model, input_size=(8, 3, 224, 224))

# %%
checkpoint_callback = ModelCheckpoint(
                                      dirpath='/content/checkpoint_model/',
                                      filename='sample-fgnet-{epoch:02d}-{val_loss:.2f}',
                                      save_top_k = 1,
                                      monitor='val_loss',
                                      mode='min'
                                      )

# %%
early_stop_callback = EarlyStopping(
                                    monitor="val_loss",
                                    mode="min",
                                    patience=10)

# %%
# from pytorch_lightning.loggers import TensorBoardLogger
# logger = TensorBoardLogger("tb_logs", name="my_model")

# %%
supervised = SupervisedLightningModule(model)
trainer = pl.Trainer(
                     max_epochs=30,
                     gpus=-1,
                     callbacks=[checkpoint_callback,early_stop_callback],
                     enable_model_summary=None)

trainer.fit(supervised, train_dataloader, val_dataloader)
# Out:
# /usr/local/lib/python3.9/dist-packages/pytorch_lightning/utilities/parsing.py:263: UserWarning: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
#   rank_zero_warn(
# /usr/local/lib/python3.9/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:474: LightningDeprecationWarning: Setting `Trainer(gpus=-1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=-1)` instead.
#   rank_zero_deprecation(
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.9/dist-packages/pytorch_lightning/trainer/trainer.py:1609: PossibleUserWarning: The number of training batches (21) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=30` reached.

# %%
def accuracy(pred: Tensor, labels: Tensor) -> float:
    return (pred.argmax(dim=-1) == labels).float().mean().item()

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/MINH/FGNET_r18_baseline_73.pth')

# %%
import shutil
import glob
t = glob.glob('/content/checkpoint_model/*')
print(t)
name = t[0].split("/")[-1]
shutil.copy(t[0], '/content/drive/MyDrive/MINH/7-3/'+name)

# %%
test2 = SupervisedLightningModule.load_from_checkpoint('/content/drive/MyDrive/MINH/7-3/sample-fgnet-epoch=39-val_loss=1.93.ckpt')
test2.eval()


test2.cuda()
acc = sum([accuracy(test2(x.cuda()), y.cuda()) for x, y in test_dataloader]) / len(test_dataloader)
print(f"Accuracy: {acc:.3f}")
#clear cache
torch.cuda.empty_cache()
# Out:
# Accuracy: 0.513

# %% [markdown]
# ### Self-Supervised Training with BYOL
#
# Perform our self-supervised training.  This is the most computationally intensive part of the script.  It takes roughly 45 minutes on a standard Colab instance with a K80 GPU.

# %%
checkpoint_callback = ModelCheckpoint(
                                      dirpath='/content/checkpoint_BYOL/',
                                      filename='BYOL-fgnet-{epoch:02d}-{val_loss:.2f}',
                                      save_top_k = 1,
                                      monitor='val_loss',
                                      mode='min'
                                      )

# %%
model_SSL = resnet18(pretrained = True)
num_ftrs = model_SSL.fc.in_features
model_SSL.fc = nn.Sequential(
               nn.Linear(num_ftrs, 256),
               nn.ReLU(inplace=True),
               nn.Dropout(0.2),
               nn.Linear(256, len(class_names)))


byol = BYOL(model_SSL, image_size=(96, 96))
trainer = pl.Trainer(
    max_epochs=50, 
    gpus=-1,
    accumulate_grad_batches=2048 // 128,
    callbacks = [checkpoint_callback],
)

trainer.fit(byol, train_dataloader, val_dataloader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.9/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:613: UserWarning: Checkpoint directory /content/checkpoint_BYOL exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type           | Params
# ---------------------------------------------
# 0 | augment   | Sequential     | 0
# 1 | encoder   | EncoderWrapper | 14.5 M
# 2 | predictor | Linear         | 65.8 K
# ---------------------------------------------
# 14.6 M    Trainable params
# 0         Non-trainable params
# 14.6 M    Total params
# 58.212    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=50` reached.

# %% [markdown]
# ### Supervised Training Again
#
# Extract the state dictionary from BYOL, and load it into our ResNet18 model before starting training.  Then run supervised training, and watch the accuracy improve from last time!

# %%
state_dict = model_SSL.state_dict()
model_improved = resnet18()
num_ftrs = model_improved.fc.in_features
model_improved.fc = nn.Sequential(
               nn.Linear(num_ftrs, 256),
               nn.ReLU(inplace=True),
               nn.Dropout(0.1),
               nn.Linear(256, len(class_names)))
model_improved.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
checkpoint_callback = ModelCheckpoint(
                                      dirpath='/content/checkpoint_improved/',
                                      filename='improved-fgnet-{epoch:02d}-{val_loss:.2f}',
                                      save_top_k = 1,
                                      monitor='val_loss',
                                      mode='min'
                                      )

# %%
supervised = SupervisedLightningModule(model_improved)
trainer = pl.Trainer(
    max_epochs=40,
    gpus=-1,
    callbacks = [checkpoint_callback, early_stop_callback],
    enable_model_summary=None,
)

trainer.fit(supervised, train_dataloader, val_dataloader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=40` reached.

# %%
torch.save(model_improved.state_dict(), '/content/drive/MyDrive/MINH/FGNET_r18_improved_73_1.pth')

# %%
import shutil
import glob
t = glob.glob('/content/checkpoint_model/*')
print(t)
name = t[0].split("/")[-1]
shutil.copy(t[0], '/content/drive/MyDrive/MINH/7-3/'+name)

# %%
test2 = SupervisedLightningModule.load_from_checkpoint('/content/drive/MyDrive/MINH/7-3/improved-fgnet-epoch=22-val_loss=1.47.ckpt')
test2.eval()


test2.cuda()
acc = sum([accuracy(test2(x.cuda()), y.cuda()) for x, y in test_dataloader]) / len(test_dataloader)
print(f"Accuracy: {acc:.3f}")
#clear cache
torch.cuda.empty_cache()
# Out:
# Accuracy: 0.519
